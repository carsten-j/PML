# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(3317)

# %%
def compute_kernel(x, gamma):
    # Reshape x to a column vector for pairwise computation
    x_column = x[:, np.newaxis]

    # Compute the pairwise squared Euclidean distances
    squared_differences = (x_column - x) ** 2

    # Compute the RBF kernel matrix
    K = np.exp(-gamma * squared_differences)

    return K

# %%
# Generate the set of values from 0 to 1.0 with increments of 0.01
x = np.arange(0, 1.01, 0.01)

# Set the kernel parameter
gamma = 10

K = compute_kernel(x, gamma)

# Number of samples to draw from the GP
n_samples = 50

# Mean vector (zero mean)
mean = np.zeros(len(x))

# Draw samples from the Gaussian Process
samples = np.random.multivariate_normal(mean, K, n_samples)

# %%
# Visualize the samples
plt.figure(figsize=(10, 5))

# Plot each sample as a function over x
for i in range(n_samples):
    plt.plot(x, samples[i], lw=1, alpha=0.6)

plt.title(
    f"{n_samples}"
    + r" Samples from Gaussian Process with mean 0 and RBF Kernel ($\gamma$"
    + f" = {gamma})"
)

plt.grid(True)
plt.tight_layout()
plt.savefig("./figures/gp_samples.png", dpi=600)
plt.show()

# %%
# Python package versions used
# %load_ext watermark
# %watermark --a "Carsten Jørgensen"
# %watermark --e "carstenj@gmail.com"
# %watermark -m -v -i -iv
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Author: Carsten Jørgensen
#
# Email: carstenj@gmail.com
#
# Python implementation: CPython
# Python version       : 3.12.4
# IPython version      : 8.25.0
#
# Compiler    : GCC 11.2.0
# OS          : Linux
# Release     : 5.15.153.1-microsoft-standard-WSL2
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 22
# Architecture: 64bit
#
# numpy     : 1.26.4
# matplotlib: 3.8.4
